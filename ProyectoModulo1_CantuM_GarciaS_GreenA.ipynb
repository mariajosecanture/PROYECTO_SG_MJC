# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://pngimage.net/wp-content/uploads/2018/06/logo-iteso-png-5.png" width="300" height="500" />
#
#
# ### <font color='navy'> Simulación de procesos financieros.
#
# **Nombres:** Maria Jose Cantu, Sofia Garcia Mora y Andrés Green
#
# **Fecha:** 2020
#
# **Expediente** : if708916, if714303 e ii713504
#
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# **LINK TAREA:** https://github.com/mariajosecanture/PROYECTO_SG_MJC
#
# # PROYECTO

# %% [markdown]
# ### 1.1 Título del trabajo.
# > Hacer distintos modelos a base de datos de las ultimas 10 temporadas de la English Premiere League, incluyendo la temporada actual utilizando *simulación MonteCarlo*.
#
#
# ### 1.2 Objetivos.
#
# > - Hacer el presente trabajo nos va a ayudar a reforzar los temas visto a lo largo del semestre en la clase de simulación de procesos financieros.
# > - Hacer una practicar real con datos de nuestro interes y modelar nodos de nuestro interes.
#
# > #### 1.1 Objetivo general.
# >  - Paracticar la creación de modelos con la ayuda de la simulación de MonteCarlo para lograr encontrar pronosticos de un equipo de la liga europea de nuestra elección.
#
# > #### 1.2 Objetivos específicos
# > - Definir nodos y variables que se desean simular.
# > - Obtener la base de datos con la que se va a trabajar.
# > - Definir equipo que se va a estudiar.
# > - Realizar el modelo para cada uno de los nodos que se definieron anteriormente con un código optimo y funcional.
# > - Mostrar los resultados de la simulación.
# > - Escribir la conclusión de nuestro proyecto.
#
#
# ### 1.3 Definición del problema.
#
#
# > En el presente proyecto se decidió modelar con respecto a los resultados de las ultimas 10 temporadas de la English Premiere League, analizando los datos historicos se buscará obtener mediante modelos los resulatdos de un equipo en especifico como local, los resulatdos del equipo como visitante, los triunfos del equipo y el numero de goles de un equipo de nuestra eleccion, en este caso Manchester City, todo lo anterior con ayuda de la *simulación MonteCarlo*.
#
# > Para realizar proyecto, es necesario identificar primeramente cúales son los supuestos de una temprorada de futbol y son los siguientes:
# - Típicamente, cuando un equipo juega en la casa (local) le va mejor, con respecto al marcador, por el contrario, cuando el equipo es visitante su marcador comunmente es más bajo.
# - Cuando un equipo tiene un buen historial en partidos pasados, comunmente sostinen ese buen desempeño.
# - Cuando el equipo cuenta con un buen director técnico todos los integrantes en conjunto mejoran y le va mejor al equipo.
#
# > Por otra parte, también es necesario definir cúales son los "nodos" o "escenarios" que se van a simular y son los siguientes:
# - Modelar la probabilidad de ganar cuando el equipo juegue en su casa (local).
# - Modlar la probabilidad de ganar cuando el equipo juegue como visitante.
# - Modelar la probabilidad de que saquen una tarjeta amarilla al equipo.
# - Modelar el número de goles que el equipo podría marcar.
#
# DIAGRAMA DE FLUJO:
# ![Screen%20Shot%202020-10-30%20at%2010.07.26%20PM.png](attachment:Screen%20Shot%202020-10-30%20at%2010.07.26%20PM.png)
#
# ### 1.4 Nodos y variables que se decidieron simular y porqué.
#
# > - En caso del primer nodo: modelar resultados cuando el equipo juegue en su casa (local), la viabilidad de la simulación es alta ya que tenemos información separada de lo triunfos/perdidas y información de cada partido con respecto a locales/visitantes.
# - Otro de los nodos es: modelar resultados cuando el equipo juegue como visitante, la viabilidad de la simulación es alta ya que tenemos información separada de lo triunfos/pérdidas y información de cada partido con respecto a locales/visitantes.
# - El tercer nodo escogido es: modelar los triunfos del equipo, lo anterior es posible ya que tenemos información acerca triunfos y perdidas de cada partido de la temporada.
# - Por último, modelar el número de goles que el equipo podría marcar.
#
# > Se escogieron los nodos en base a la información dispoknible y también la que nos interesa saber.
#
# ### 1.5 Definición de hipótesis y supuestos.
# >  Para poder modelar un proceso de negocio o cualquiera otro proceso en el área de las ingenierías o ciencias sociales, después de identificar el objeto de estudio, es importante indicar cuales son los supuestos que se dan por verdaderos a lo largo de la ejecución del proceso. Estos supuestos se deben indicar en forma de variables e hipótesis (son diferentes), porque si puedes definir en un valor el supuesto lo llamaremos "supuesto constante" y si no es posible identificarlo con un número entonces será una hipótesis que afectará la construcción de los escenarios posibles del proceso.

# %% [markdown]
# ### 1.6 Obtención de bases de datos
# > El tercer paso del proyecto es indicar de dónde se obtendrán las bases de datos, que indican como se han comportado las variables que identificaste en tu proceso de negocio que vas a simular. En esta investigación debes haber encontrado información propia de la empresa, organización o institución que vas a simular y otra parte de la información debe provenir de investigación que realices en fuentes de información públicas o privadas como las que tiene SECOBI, ahí normalmente y dependiendo del problema elegido, se investigan variables económicas, como tasas de interés, inflación, tipo de cambio, etc., de varios años, por poner un ejemplo.
#
# Para este proyecto, se recaudaron datos de DATAHUB pero en realidad son provinientes de http://www.football-data.co.uk
#
# El conjunto de datos encontrado, contiene datos de las últimas 10 temporadas de la English Premier League, incluida la temporada actual. Para el proyecto presente se decidió modelar 4 nodos con respecto a un equipo de 20 de nuestra elección, el cual fue: Manchester City. Concideramos que el equipo mencionado es el más consistente de la liga es por eso que fue elegído.
#
# El club de Manchester City fue fundando el 23 de noviembre de 1894 y actualmente su casa es el estadio Etihad desde el 2003 y esta ubicado en la ciudad de Mánchester en Reino Unido.
#
# Desde la llegada de los nuevos dueños en el 2008, el club ha obtenido un total de 14 títulos oficiales, ganando la Premier League en 2012, 2014, 2018 y 2019.
#
# Financieramente, el club resulta ser uno de los más ricos del mundo
#
# Dado el cambio de dueños en el 2008 se decidió obtener datos desde ese año ya que es a partir de ahi que el equipo de Manchester City creció.

# %%
import numpy as np
from functools import reduce
import time
import matplotlib.pyplot as plt
import scipy.stats as st
import pandas as pd
from scipy import optimize

# %%
# Importaremos los datos desde el 2008 
import pandas as pd

data0809 = pd.read_csv('data/2008-09.csv')

data0910 = pd.read_csv('data/2009-10.csv')

data1011 = pd.read_csv('data/2010-11.csv')

data1112 = pd.read_csv('data/2011-12.csv')

data1213 = pd.read_csv('data/2012-13.csv')

data1314 = pd.read_csv('data/2013-14.csv')

data1415 = pd.read_csv('data/2014-15.csv')

data1516 = pd.read_csv('data/2015-16.csv')

data1617 = pd.read_csv('data/2016-17.csv')

data1718 = pd.read_csv('data/2017-18.csv')

data1819 = pd.read_csv('data/2018-19.csv')

data1920 = pd.read_csv('data/2019-20.csv')

# Creación de DataFrame para desplegar todos los años juntos para simplificar

data = data1617.append([data0809, data0910, data1011, data1112, data1213, data1314, data1516, data1617, data1718, data1819,data1920])

data = data.fillna('') #Llenar espacios vaciós con '' para hacer leída más fácil

# Crear DataFrame que solo contenga datos de Manchester City

datahome = data.loc[data['HomeTeam'] == 'Man City']

dataaway = data.loc[data['AwayTeam'] == 'Man City']

data_mancity = datahome.append([dataaway])

data_mancity.head(10)
# Out:
# //anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#      AC  AF AHCh AHh  AR  AS  AST  AY Avg<2.5 Avg>2.5  ... VCCD VCCH   VCD  \
# 4     6  14            0   7    3   2                  ...             6.5
# 28    4  10            0   9    2   3                  ...               6
# 44    5  11            0   6    2   1                  ...            6.25
# 74    1   9            0   3    2   2                  ...             4.8
# 89    3  10            0   6    2   3                  ...             4.6
# 103   2  15            0   5    3   3                  ...               7
# 131   2   9            0  10    4   3                  ...             3.5
# ...

# %% [markdown]
# Para que se logre entender nuestros datos, se muestra una imagen con lo que significa cada parte de nuestro data frame.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1.7 Visualización de resultados de simulación.
# > Se deben simular al menos 4  "nodos" o "escenarios" en tu problema. Para la segunda entrega debes haber elaborado un programa que simule dos de ellos, los primeros dos de tu diagrama.
# > Para la entrega final deben de tener los 4 nodos con todas sus simulaciones.
#
# ## Modelar la probabilidad de ganar cuando el equipo juegue en su casa (local).

# %% [markdown]
# ##### FRECUENCIA: FTR (FULL TIME RESULT)
#
# H: Home win
# D: Draw
# A: Away win

# %%
data_mancity_ftr = data_mancity[['HomeTeam','AwayTeam','FTR']]
data_mancity_ftr.tail()
# Out:
#              HomeTeam  AwayTeam FTR
# 168           Arsenal  Man City   A
# 188            Wolves  Man City   H
# 218       Aston Villa  Man City   A
# 233  Sheffield United  Man City   A
# 249         Tottenham  Man City   H

# %%
data_mancity_ftr.loc[data_mancity_ftr['FTR'] == "H"]

datahome_ftr = datahome[['Date','HomeTeam','FTR']]
datahome_ftr

datahome_h=sum([datahome_ftr['FTR'] == 'H'])
datahome_h=sum(datahome_h==1)


datahome_a=sum([datahome_ftr['FTR'] == 'A'])
datahome_a=sum(datahome_a==1)


datahome_d=sum([datahome_ftr['FTR'] == 'D'])
datahome_d=sum(datahome_d==1)

print("Partidos ganados de Manchester City en casa desde el 2008: ",datahome_h)
print("Partidos empatados de Manchester City en casa desde el 2008: ",datahome_d)
print("Partidos perdidos de Manchester City en casa desde el 2008: ",datahome_a)
# Out:
# Partidos ganados de Manchester City en casa desde el 2008:  154
# Partidos empatados de Manchester City en casa desde el 2008:  33
# Partidos perdidos de Manchester City en casa desde el 2008:  24

# %%
total= (datahome_h+datahome_a+datahome_d)

prob_a = datahome_a/total
prob_h = datahome_h/total
prob_d = datahome_d/(total)

print("Probabiliad acumulada de que Manches city gane en casa: ",prob_h)
print("Probabiliad acumulada de que Manches city pierda en casa: ", prob_a)
print("Probabiliad acumulada de que haya un empate en casa:", prob_d)
# Out:
# Probabiliad acumulada de que Manches city gane en casa:  0.7298578199052133
# Probabiliad acumulada de que Manches city pierda en casa:  0.11374407582938388
# Probabiliad acumulada de que haya un empate en casa: 0.15639810426540285

# %% [markdown]
# ##### VARIABLE: HTR (HALF TIME RESULT)
#
# H: Home win
# D: Draw
# A: Away win

# %%
data_mancity_htr = data_mancity[['HomeTeam','AwayTeam','HTR']]
data_mancity_htr.loc[data_mancity_htr['HTR'] == "H"]

datahome_htr = datahome[['Date','HomeTeam','HTR']]

datahome_htr_h=sum([datahome_htr['HTR'] == 'H'])
datahome_htr_h=sum(datahome_htr_h==1)


datahome_htr_a=sum([datahome_htr['HTR'] == 'A'])
datahome_htr_a=sum(datahome_htr_a==1)


datahome_htr_d=sum([datahome_htr['HTR'] == 'D'])
datahome_htr_d=sum(datahome_htr_d==1)

print("Partidos ganados en el medio tiempo de Manchester City en casa desde el 2008: ",datahome_htr_h)
print("Partidos empatados en el medio tiempo de Manchester City en casa desde el 2008: ",datahome_htr_d)
print("Partidos perdidos en el medio timepo de Manchester City en casa desde el 2008: ",datahome_htr_a)
# Out:
# Partidos ganados en el medio tiempo de Manchester City en casa desde el 2008:  123
# Partidos empatados en el medio tiempo de Manchester City en casa desde el 2008:  65
# Partidos perdidos en el medio timepo de Manchester City en casa desde el 2008:  23

# %%
dfg= (datahome_htr['HTR'])
plt.hist(dfg,density=True)
plt.xlabel('HTR')
plt.ylabel('FTR')
plt.title('Impacto')
plt.show()

# %% [markdown]
# ##### VARIABLE: HS (HOME TEAM SHOTS)

# %%
datahome_hs = datahome[['HomeTeam','HS']]

print("Cantidad de tiros de Manchester city en cada partido:")
datahome_hs.head()
# Out:
# Cantidad de tiros de Manchester city en cada partido:
#     HomeTeam  HS
# 4   Man City  16
# 28  Man City  22
# 44  Man City  20
# 74  Man City  19
# 89  Man City  14

# %% [markdown]
# ##### VARIABLE: HF (HOME TEAM FOULS COMMITED)

# %%
datahome_hf = datahome[['HomeTeam','HF']]

print("Cantidad de 'fouls' marcados al Manchester city en cada partido:")
datahome_hf.head()
# Out:
# Cantidad de 'fouls' marcados al Manchester city en cada partido:
#     HomeTeam  HF
# 4   Man City  11
# 28  Man City   5
# 44  Man City   8
# 74  Man City   7
# 89  Man City  11

# %% [markdown]
# ##### HTR (HALF TIME RESULT) vs FTR (FULL TIME RESULT)
#
# H: Home win
# D: Draw
# A: Away win

# %%
datahome_ftr_htr= datahome[['HomeTeam','FTR','HTR']]
datahome_ftr_htr.tail()
# Out:
#      HomeTeam FTR HTR
# 176  Man City   H   H
# 198  Man City   H   D
# 204  Man City   H   D
# 222  Man City   D   A
# 259  Man City   H   H

# %%
HH=0
HD=0
HA=0
i=0
for i in range (len(datahome_ftr_htr)):
    
    if datahome_ftr_htr.iloc[i]['FTR'] == 'H' and datahome_ftr_htr.iloc[i]['HTR']== 'H':
        HH+=1
    elif datahome_ftr_htr.iloc[i]['FTR'] == 'H' and datahome_ftr_htr.iloc[i]['HTR']== 'D':
        HD+=1
    elif datahome_ftr_htr.iloc[i]['FTR'] == 'H' and datahome_ftr_htr.iloc[i]['HTR']== 'A':
        HA+=1
    i+=1

# %%
prob_homeftr_homehtr=HH/datahome_h
prob_homeftr_drawhtr=HD/datahome_h
prob_homeftr_awayhtr=HA/datahome_h

print("Probabilidad de que gane el partido después de estar ganando en medio tiempo: ",prob_homeftr_homehtr)
print("Probabilidad de que gane el partido después de ir perdiendo en medio tiempo: ",prob_homeftr_awayhtr)
print("Probabilidad de que gane el partido después de estar empatado en medio tiempo: ",prob_homeftr_drawhtr)
# Out:
# Probabilidad de que gane el partido después de estar ganando en medio tiempo:  0.7207792207792207
# Probabilidad de que gane el partido después de ir perdiendo en medio tiempo:  0.032467532467532464
# Probabilidad de que gane el partido después de estar empatado en medio tiempo:  0.24675324675324675

# %% [markdown]
# ##### HS (HOME TEAM SHOTS) vs FTR (FULL TIME RESULT)

# %%
datahome_ftr_hs= datahome[['HomeTeam','FTR','HS']]
datahome_ftr_hs.tail()
# Out:
#      HomeTeam FTR  HS
# 176  Man City   H  23
# 198  Man City   H  16
# 204  Man City   H  16
# 222  Man City   D  25
# 259  Man City   H  20

# %%
HS_H=0
HS_D=0
HS_A=0
i=0
for i in range (len(datahome_ftr_hs)):
    
    if datahome_ftr_hs.iloc[i]['FTR'] == 'H':
        HS_H+= datahome_ftr_hs.iloc[i]['HS']
    if datahome_ftr_hs.iloc[i]['FTR'] == 'D':
        HS_D+= datahome_ftr_hs.iloc[i]['HS']
    elif datahome_ftr_hs.iloc[i]['FTR'] == 'A':
        HS_A+= datahome_ftr_hs.iloc[i]['HS']
    i+=1

# %%
shots_h=HS_H/datahome_h
shots_d=HS_D/datahome_d
shots_a=HS_A/datahome_a

print("Promedio de cantidad de tiros de Manchester city cuando juega en casa y gana: ",shots_h)
print("Promedio de cantidad de tiros de Manchester city cuando juega en casa y empata: ",shots_d)
print("Promedio de cantidad de tiros de Manchester city cuando juega en casa y pierde: ",shots_a)
# Out:
# Promedio de cantidad de tiros de Manchester city cuando juega en casa y gana:  17.649350649350648
# Promedio de cantidad de tiros de Manchester city cuando juega en casa y empata:  16.515151515151516
# Promedio de cantidad de tiros de Manchester city cuando juega en casa y pierde:  15.375

# %% [markdown]
# ##### HF (HOME TEAM FOULS COMMITED) vs FTR (FULL TIME RESULT)

# %%
datahome_ftr_hf= datahome[['HomeTeam','FTR','HF']]
datahome_ftr_hf.tail()
# Out:
#      HomeTeam FTR  HF
# 176  Man City   H  14
# 198  Man City   H   5
# 204  Man City   H  11
# 222  Man City   D   9
# 259  Man City   H   5

# %%
HF_H=0
HF_D=0
HF_A=0
i=0
for i in range (len(datahome_ftr_hf)):
    
    if datahome_ftr_hf.iloc[i]['FTR'] == 'H':
        HF_H+= datahome_ftr_hf.iloc[i]['HF']
    if datahome_ftr_hf.iloc[i]['FTR'] == 'D':
        HF_D+= datahome_ftr_hf.iloc[i]['HF']
    elif datahome_ftr_hf.iloc[i]['FTR'] == 'A':
        HF_A+= datahome_ftr_hf.iloc[i]['HF']
    i+=1

# %%
fouls_h=HF_H/datahome_h
fouls_d=HF_D/datahome_d
fouls_a=HF_A/datahome_a

print("Promedio de fouls de Manchester city cuando juega en casa y gana: ",fouls_h)
print("Promedio de fouls de Manchester city cuando juega en casa y empata: ",fouls_d)
print("Promedio de fouls de Manchester city cuando juega en casa y pierde: ",fouls_a)
# Out:
# Promedio de fouls de Manchester city cuando juega en casa y gana:  9.928571428571429
# Promedio de fouls de Manchester city cuando juega en casa y empata:  10.787878787878787
# Promedio de fouls de Manchester city cuando juega en casa y pierde:  11.083333333333334

# %% [markdown]
# ### MODELO:

# %%
def Prima(E,G,C,V):
    if E>18 and E<=30:
        P=0.015
    else:
        if E>30 and E<=60:
            P=0.02
        else:
            P=0
    if G==1:
        P=P+0.03
    else:
        P=P+0.01
    if C==1:
        P=P+0.27
    else:
        P=P+0.15
        
    return((P*V)/12)

# %% [markdown]
# ## Modelar la probabilidad de ganar cuando el equipo juegue como visitante.

# %% [markdown]
# ##### FRECUENCIA: FTR (FULL TIME RESULT)
#
# H: Home win
# D: Draw
# A: Away win

# %%
dataaway_ftr = dataaway[['AwayTeam','FTR']]

dataaway_h=sum([dataaway_ftr['FTR'] == 'H'])
dataaway_h=sum(dataaway_h==1)


dataaway_a=sum([dataaway_ftr['FTR'] == 'A'])
dataaway_a=sum(dataaway_a==1)


dataaway_d=sum([dataaway_ftr['FTR'] == 'D'])
dataaway_d=sum(dataaway_d==1)

print("Partidos ganados de Manchester City fuera de casa desde el 2008: ",dataaway_h)
print("Partidos empatados de Manchester City fuera de casa desde el 2008: ",dataaway_d)
print("Partidos perdidos de Manchester City fuera de casa desde el 2008: ",dataaway_a)
# Out:
# Partidos ganados de Manchester City fuera de casa desde el 2008:  58
# Partidos empatados de Manchester City fuera de casa desde el 2008:  48
# Partidos perdidos de Manchester City fuera de casa desde el 2008:  105

# %%
total_a= (dataaway_h+dataaway_a+dataaway_d)

prob_away_a = dataaway_a/total_a
prob_away_h = dataaway_h/total_a 
prob_away_d = dataaway_d/total_a


print("Probabiliad acumulada de que Manchester city gane fuera de casa: ",prob_away_h)
print("Probabiliad acumulada de que Manchester city pierda fuera de casa: ", prob_away_a)
print("Probabiliad acumulada de que haya un empate fuera de casa:", prob_away_d)
# Out:
# Probabiliad acumulada de que Manches city gane fuera de casa:  0.27488151658767773
# Probabiliad acumulada de que Manches city pierda fuera de casa:  0.4976303317535545
# Probabiliad acumulada de que haya un empate fuera de casa: 0.22748815165876776

# %% [markdown]
# ##### VARIABLE: HTR (HALF TIME RESULT)
#
# H: Home win
# D: Draw
# A: Away win

# %%
data_mancity_htr = data_mancity[['HomeTeam','AwayTeam','HTR']]
data_mancity_htr.loc[data_mancity_htr['HTR'] == "H"]

dataaway_htr = datahome[['Date','AwayTeam','HTR']]

dataaway_htr_h=sum([dataaway_htr['HTR'] == 'H'])
dataaway_htr_h=sum(dataaway_htr_h==1)


dataaway_htr_a=sum([dataaway_htr['HTR'] == 'A'])
dataaway_htr_a=sum(dataaway_htr_a==1)


dataaway_htr_d=sum([dataaway_htr['HTR'] == 'D'])
dataaway_htr_d=sum(dataaway_htr_d==1)

print("Partidos ganados en el medio tiempo de Manchester City fuera de casa desde el 2008: ",dataaway_htr_h)
print("Partidos empatados en el medio tiempo de Manchester City fuera de casa desde el 2008: ",dataaway_htr_d)
print("Partidos perdidos en el medio timepo de Manchester City fuera de casa desde el 2008: ",dataaway_htr_a)
# Out:
# Partidos ganados en el medio tiempo de Manchester City fuera de casa desde el 2008:  123
# Partidos empatados en el medio tiempo de Manchester City fuera de casa desde el 2008:  65
# Partidos perdidos en el medio timepo de Manchester City fuera de casa desde el 2008:  23

# %% [markdown]
# ##### VARIABLE: AS (AWAY TEAM SHOTS)

# %%
dataaway_as = dataaway[['AwayTeam','AS']]

print("Cantidad de tiros de Manchester city en cada partido:")
dataaway_hs.head()
# Out:
# Cantidad de tiros de Manchester city en cada partido:
#     AwayTeam  AS
# 13  Man City  12
# 34  Man City  18
# 57  Man City  18
# 69  Man City  12
# 96  Man City  21

# %% [markdown]
# ##### VARIABLE: AF (AWAY TEAM FOULS COMMITED)

# %%
dataaway_hf = datahome[['AwayTeam','HF']]

print("Cantidad de 'fouls' marcados al Manchester city en cada partido:")
dataaway_hf.head()
# Out:
# Cantidad de 'fouls' marcados al Manchester city en cada partido:
#        AwayTeam  HF
# 4    Sunderland  11
# 28     West Ham   5
# 44  Bournemouth   8
# 74      Everton   7
# 89  Southampton  11

# %% [markdown]
# ##### HTR (HALF TIME RESULT) vs FTR (FULL TIME RESULT)
#
# H: Home win
# D: Draw
# A: Away win

# %%
dataaway_ftr_htr= dataaway[['AwayTeam','FTR','HTR']]
dataaway_ftr_htr.tail()
# Out:
#      AwayTeam FTR HTR
# 168  Man City   A   A
# 188  Man City   H   A
# 218  Man City   A   A
# 233  Man City   A   D
# 249  Man City   H   D

# %%
AH=0
AD=0
AA=0
j=0
for i in range (len(dataaway_ftr_htr)):
    
    if dataaway_ftr_htr.iloc[i]['FTR'] == 'A' and dataaway_ftr_htr.iloc[i]['HTR']== 'H':
        AH+=1
    elif dataaway_ftr_htr.iloc[i]['FTR'] == 'A' and dataaway_ftr_htr.iloc[i]['HTR']== 'D':
        AD+=1
    elif dataaway_ftr_htr.iloc[i]['FTR'] == 'A' and dataaway_ftr_htr.iloc[i]['HTR']== 'A':
        AA+=1
    j+=1

# %%
prob_awayftr_homehtr=AH/dataaway_a
prob_awayftr_drawhtr=AD/dataaway_a
prob_awayftr_awayhtr=AA/dataaway_a

print("Probabilidad de que gane el partido después de estar ganando en medio tiempo: ",prob_awayftr_awayhtr)
print("Probabilidad de que gane el partido después de ir perdiendo en medio tiempo: ",prob_awayftr_homehtr)
print("Probabilidad de que gane el partido después de estar empatado en medio tiempo: ",prob_awayftr_drawhtr)
# Out:
# Probabilidad de que gane el partido después de estar ganando en medio tiempo:  0.7047619047619048
# Probabilidad de que gane el partido después de ir perdiendo en medio tiempo:  0.009523809523809525
# Probabilidad de que gane el partido después de estar empatado en medio tiempo:  0.2857142857142857

# %% [markdown]
# ##### AS (AWAY TEAM SHOTS) vs FTR (FULL TIME RESULT)

# %%
dataaway_ftr_as= dataaway[['AwayTeam','FTR','AS']]
dataaway_ftr_as.tail()
# Out:
#      AwayTeam FTR  AS
# 168  Man City   A  14
# 188  Man City   H   7
# 218  Man City   A  22
# 233  Man City   A  18
# 249  Man City   H  18

# %%
AS_H=0
AS_D=0
AS_A=0
i=0
for i in range (len(dataaway_ftr_as)):
    
    if dataaway_ftr_as.iloc[i]['FTR'] == 'H':
        AS_H+= dataaway_ftr_as.iloc[i]['AS']
    if dataaway_ftr_as.iloc[i]['FTR'] == 'D':
        AS_D+= dataaway_ftr_as.iloc[i]['AS']
    elif dataaway_ftr_as.iloc[i]['FTR'] == 'A':
        AS_A+= dataaway_ftr_as.iloc[i]['AS']
    i+=1

# %%
shots_h=AS_H/dataaway_h
shots_d=AS_D/dataaway_d
shots_a=AS_A/dataaway_a

print("Promedio de cantidad de tiros de Manchester city cuando juega fuera de casa y gana: ",shots_h)
print("Promedio de cantidad de tiros de Manchester city cuando juega fuera de casa y empata: ",shots_d)
print("Promedio de cantidad de tiros de Manchester city cuando juega fuera de casa y pierde: ",shots_a)
# Out:
# Promedio de cantidad de tiros de Manchester city cuando juega fuera de casa y gana:  13.431034482758621
# Promedio de cantidad de tiros de Manchester city cuando juega fuera de casa y empata:  13.479166666666666
# Promedio de cantidad de tiros de Manchester city cuando juega fuera de casa y pierde:  15.80952380952381

# %% [markdown]
# ##### AF (HOME TEAM FOULS COMMITED) vs FTR (FULL TIME RESULT)

# %%
dataaway_ftr_af= dataaway[['AwayTeam','FTR','AF']]
dataaway_ftr_af.tail()
# Out:
#      AwayTeam FTR  AF
# 168  Man City   A  24
# 188  Man City   H  13
# 218  Man City   A  12
# 233  Man City   A  13
# 249  Man City   H  14

# %%
AF_H=0
AF_D=0
AF_A=0
i=0
for i in range (len(dataaway_ftr_af)):
    
    if dataaway_ftr_af.iloc[i]['FTR'] == 'H':
        AF_H+= dataaway_ftr_af.iloc[i]['AF']
    if dataaway_ftr_af.iloc[i]['FTR'] == 'D':
        AF_D+= dataaway_ftr_af.iloc[i]['AF']
    elif dataaway_ftr_af.iloc[i]['FTR'] == 'A':
        AF_A+= dataaway_ftr_af.iloc[i]['AF']
    i+=1

# %%
fouls_h=AF_H/dataaway_h
fouls_d=AF_D/dataaway_d
fouls_a=AF_A/dataaway_a

print("Promedio de fouls de Manchester city cuando juega fuera de casa y gana: ",fouls_h)
print("Promedio de fouls de Manchester city cuando juega fuera de casa y empata: ",fouls_d)
print("Promedio de fouls de Manchester city cuando juega fuera de casa y pierde: ",fouls_a)
# Out:
# Promedio de fouls de Manchester city cuando juega fuera de casa y gana:  11.241379310344827
# Promedio de fouls de Manchester city cuando juega fuera de casa y empata:  10.75
# Promedio de fouls de Manchester city cuando juega fuera de casa y pierde:  11.076190476190476

# %% [markdown]
# ### MODELO:

# %% [markdown]
# #### Modelar el posicionamiento en la tabla del equipo al final de la temporada.

# %% [markdown]
# #### Modelar el número de goles que el equipo podría marcar.

# %% [markdown]
# ### 1.6 Conclusiones.
# > Mucho cuidado, las conclusiones no son cualquier cosa. Se debe concluir respecto a los objetivos planteados de acuerdo a los resultados obtenidos.

# %% [markdown]
# ### 1.7 Referencias.
# > Citar (en formato APA) la bibliografía utilizada.
#
# https://es.wikipedia.org/wiki/Manchester_City_Football_Club

# %% [markdown]
# https://datahub.io/sports-data/english-premier-league#resource-season-1718
